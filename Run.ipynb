# %%
import train

# %%
train.main()
# Out:
# Reading test images
# 1231874543519.upx
# جنتورة
# 1231874635809.upx
# ماطر
# 1231874659146.upx
# توزر
# 1231874942177.upx
# تاجروين
# 1231875027369.upx
# سوسة
# 1231875133043.upx
# شرفش
# 1232010585404.upx
# تبرسق
# 1232010669909.upx
# زلبة
# 1232011164414.upx
# رمادة
# 1232011222695.upx
# مطماطة
# (10, 240, 240, 3)
# 900
# 64
# 14
# cnn_learning/Variable:0
# cnn_learning/Variable_1:0
# cnn_learning/Variable_2:0
# cnn_learning/Variable_3:0
# cnn_learning/Variable_4:0
# cnn_learning/Variable_5:0
# input_embedding/Variable:0
# target_embedding/Variable:0
# encoder_decoder/encoder/rnn/lstm_cell/weights:0
# encoder_decoder/encoder/rnn/lstm_cell/biases:0
# encoder_decoder/decoder/rnn/lstm_cell/weights:0
# encoder_decoder/decoder/rnn/lstm_cell/biases:0
# logits/fully_connected/weights:0
# logits/fully_connected/biases:0
# ...
# <function get_default_graph at 0x7f86cc4ca8c8>
# Epoch   0 Loss:  3.969 Epoch duration:  4.622s
#    sample 1
# ...
